# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("MarketTop2000.csv")

# %%
df.rename(columns = {'Sub-Sector':'sector'}, inplace = True)

# %% [markdown]
# # ##  Top sectors having largest Market capital

# %%
df1 = df.groupby('sector')['Market Cap'].max().reset_index().sort_values(by='Market Cap', ascending=False)
df2 = df1.set_index('sector', inplace=True)

# %%
df1
# Out:
#                                    Market Cap
# sector
# Oil & Gas - Re?ning & Marketing  1.679534e+06
# IT Services & Consulting         1.358569e+06
# Private Banks                    8.206363e+05
# FMCG - Household Products        4.938958e+05
# Public Banks                     4.479263e+05
# ...                                       ...
# 0                                6.146127e+02
# Airports                         3.948000e+02
# Three Wheelers                   3.757773e+02
# Retail - Online                  2.992004e+02
# Metals - Iron                    2.367804e+02
#
# [137 rows x 1 columns]

# %% [markdown]
# ## sector having lowest Market capital

# %%
df3 = df.groupby('sector')['Market Cap'].min().reset_index().sort_values(by='Market Cap', ascending=True)

# %%
df4 = df3.set_index('sector', inplace=True)

# %%
#df3.plot(kind='bar', title='sector with lowest capital',ylabel='Market in crores', xlabel='sector', figsize=(25, 7))
#plt.rc('xtick', labelsize=10) 
#plt.rc('ytick', labelsize=20)

# %% [markdown]
# ## frequency of sectors in the market and total market capital value

# %%
df5 = df.groupby('sector')['Market Cap'].describe()
#df6 = df5[df5.Name != 'Swiss Military Consumer Goods Ltd']
df5 = df5.iloc[1:, :]

# %%
#drop multiple columns by name
df6 = df5.drop(['mean', 'std','25%','50%','75%','min','max'], axis=1, inplace=True)

# %%
df5.plot(kind='bar', title='Frequency of Sector',ylabel='Total capital in crores', xlabel='sector', figsize=(25, 7))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=20)
plt.rc('font', size=25)

# %% [markdown]
# # Most capital is utilised in agrregate pharmaceautical sector of around 100 crores

# %%
## Top 10 large cap companies with capital

dfsegment = df.groupby('Name')['Market Cap'].sum().reset_index().sort_values(by='Market Cap', ascending=False)

# %%
df_large = dfsegment[dfsegment['Market Cap'] > 20000]

# %%
datalarge = df_large.set_index('Name', inplace=True)
dfbig = df_large.head(10)

# %%
#dfbig.plot(kind="pie", autopct='%1.1f%%', y = 'Market Cap', shadow=True,  legend=True, title='Frequency of sector ', ylabel='', labeldistance=None,
#                 colors = ['red', 'pink', 'steelblue','black','yellow','grey','brown','green','orange','purple'])
#dfbig.plot(kind='bar', title='Frequency of Sector',ylabel='capital in crores', xlabel='sector', figsize=(25, 7))
plt.rc('xtick', labelsize=10) 
plt.rc('ytick', labelsize=10)
plt.rc('font', size=10) 
colors = ['red', 'pink', 'steelblue','black','yellow','grey','brown','green','orange','purple']
data = dfbig["Market Cap"]
ax = data.plot(kind="pie",y = 'Market Cap' ,autopct='%1.1f%%', shadow=True, colors=colors, legend=True, title='top large cap', ylabel='', labeldistance=None)
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.show()

# %%
## top 10 samllcap companies

# %%
df_small = dfsegment[dfsegment['Market Cap'] < 5000]

# %%
datasmall = df_small.set_index('Name', inplace=True)
dfsmall = df_small.head(10)

# %%
colors = ['red', 'pink', 'steelblue','black','yellow','grey','brown','green','orange','purple']
data = dfbig["Market Cap"]
ax = dfsmall.plot(kind="pie",y = 'Market Cap' ,autopct='%1.1f%%', shadow=True, colors=colors, legend=True, title='top small cap', ylabel='', labeldistance=None)
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.rc('xtick', labelsize=10) 
plt.rc('ytick', labelsize=10)
plt.rc('font', size=10) 
plt.show()

# %%
## top 10 midcap companies

# %%
df_mid = dfsegment[dfsegment['Market Cap'] < 20000 ]

# %%
df_mid = df_mid[dfsegment['Market Cap'] > 5000 ]
# Out:
# C:\Users\Keshav Pathak\AppData\Local\Temp\ipykernel_5180\2931063013.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_mid = df_mid[dfsegment['Market Cap'] > 5000 ]

# %%
datamid = df_mid.set_index('Name', inplace=True)
dfmid = df_mid.head(10)

# %%
colors = ['red', 'pink', 'steelblue','black','yellow','grey','brown','green','orange','purple']
data = dfbig["Market Cap"]
ax = dfmid.plot(kind="pie",y = 'Market Cap' ,autopct='%1.1f%%', shadow=True, colors=colors, legend=True, title='top Mid cap', ylabel='', labeldistance=None)
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.rc('xtick', labelsize=10) 
plt.rc('ytick', labelsize=10)
plt.rc('font', size=10) 
plt.show()
